# %%
pd.set_option('display.max_columns', 500)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
from google.cloud import bigquery
from google.oauth2 import service_account

# %%
key_path = './service_account/gentle-keyword-423715-j0-03be08ad6412.json'

credentials = service_account.Credentials.from_service_account_file(
    key_path,
    scopes=["https://www.googleapis.com/auth/bigquery"]
)

# %%
from google.cloud import bigquery

client = bigquery.Client(
    credentials = credentials,
    project=credentials.project_id
)

# %%
query = """
SELECT
  u.id user_id,
  u.country,
  u.gender,
  u.traffic_source,
  DATE(EXTRACT(YEAR FROM u.created_at), EXTRACT(MONTH FROM u.created_at), 1) created_account_date,
  u.age,
  o.order_id,
  o.num_of_item,
  DATE(EXTRACT(YEAR FROM o.created_at), EXTRACT(MONTH FROM o.created_at), 1) order_date,
  oi.sale_price * o.num_of_item revenue,
  e.session_id,
FROM `bigquery-public-data.thelook_ecommerce.users` u
LEFT JOIN `bigquery-public-data.thelook_ecommerce.order_items` oi
  ON oi.user_id = u.id
LEFT JOIN `bigquery-public-data.thelook_ecommerce.orders` o
  ON u.id = o.user_id AND oi.order_id = o.order_id
INNER JOIN `bigquery-public-data.thelook_ecommerce.products` p
  ON oi.product_id = p.id
LEFT JOIN `bigquery-public-data.thelook_ecommerce.events` e
  ON u.id = e.id
WHERE 
  o.status = 'Complete'
  AND
  (EXTRACT(YEAR FROM o.created_at) >= 2023)
"""

df = client.query(query).to_dataframe()
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28354 entries, 0 to 28353
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   user_id               28354 non-null  Int64
#  1   country               28354 non-null  object
#  2   gender                28354 non-null  object
#  3   traffic_source        28354 non-null  object
#  4   created_account_date  28354 non-null  dbdate
#  5   age                   28354 non-null  Int64
#  6   order_id              28354 non-null  Int64
#  7   num_of_item           28354 non-null  Int64
#  8   order_date            28354 non-null  dbdate
#  9   revenue               28354 non-null  float64
#  10  session_id            28354 non-null  object
# dtypes: Int64(4), dbdate(2), float64(1), object(4)
# memory usage: 2.5+ MB
# None
#    user_id  country gender traffic_source created_account_date  age  order_id  \
# 0    78970   Brasil      F         Search           2022-08-01   63     98526
# 1    42208  Germany      F          Email           2022-08-01   48     52665
# 2    78970   Brasil      F         Search           2022-08-01   63     98526
# 3    78970   Brasil      F         Search           2022-08-01   63     98526
# 4    95142    China      M         Search           2022-08-01   45    118710
#
#    num_of_item  order_date    revenue                            session_id
# 0            4  2023-11-01  48.000000  ed6667f5-08bd-422e-a7ef-e77157af152f
# 1            1  2023-03-01  15.950000  c30d4b63-7750-459a-b184-5dac82005120
# 2            4  2023-11-01  71.080002  ed6667f5-08bd-422e-a7ef-e77157af152f
# 3            4  2023-11-01  88.000000  ed6667f5-08bd-422e-a7ef-e77157af152f
# 4            1  2023-01-01  25.000000  83ce05ee-47b7-41f6-ab3a-47f16a90b3b4

# %%
df['order_id'] = df['order_id'].astype(str)
df['user_id'] = df['user_id'].astype(str)
df['order_date'] = pd.to_datetime(df['order_date'])
df['created_account_date'] = pd.to_datetime(df['created_account_date'])

print("Number of unique user_id: ", df['user_id'].nunique())

print(df.info())
# Out:
# Number of unique user_id:  17802
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28354 entries, 0 to 28353
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   user_id               28354 non-null  object
#  1   country               28354 non-null  object
#  2   gender                28354 non-null  object
#  3   traffic_source        28354 non-null  object
#  4   created_account_date  28354 non-null  datetime64[ns]
#  5   age                   28354 non-null  Int64
#  6   order_id              28354 non-null  object
#  7   num_of_item           28354 non-null  Int64
#  8   order_date            28354 non-null  datetime64[ns]
#  9   revenue               28354 non-null  float64
#  10  session_id            28354 non-null  object
# dtypes: Int64(2), datetime64[ns](2), float64(1), object(6)
# memory usage: 2.4+ MB
# None

# %%
from sklearn.preprocessing import StandardScaler

# Create helper function
def categorized_country(x):
    if x in ['China', 'United States', 'Brasil']:
        return x
    else:
        return 'Others'
    
# Aggregating
map_agg = {
    'country': 'first',
    'gender': 'first',
    'traffic_source': pd.Series.mode,
    'created_account_date': 'min',
    'age': 'first',
    'order_id': 'nunique',
    'num_of_item': 'sum',
    'order_date': 'max',
    'revenue': 'sum',
    'session_id': 'count'
}

df_grouped = df.groupby('user_id')\
                .agg(map_agg)\
                .reset_index()

# new_columns = []
# for c in df_grouped.columns:
#     if (c[-1] == '') or (c[-1] in ['first', 'max', 'min', 'nunique', 'mode']):
#         new_columns.append(c[0])
#         continue
#     new_columns.append(c[0] + '_' + c[1])

# df_grouped.columns = new_columns

# Feature Engineering
currentDate = df['order_date'].max()
df_grouped['recency'] = round((currentDate - df_grouped['order_date'])) / pd.to_timedelta(1, 'day')
df_grouped['age_account'] = round((currentDate - df_grouped['created_account_date'])) / pd.to_timedelta(1, 'day')
df_grouped['diff_last_order_to_create'] = round((df_grouped['order_date'] - df_grouped['created_account_date'])) / pd.to_timedelta(1, 'day')
df_grouped['country'] = df_grouped['country'].apply(categorized_country)

df_grouped = df_grouped.drop(['order_date', 'created_account_date'], axis=1)\
                        .rename(columns={'num_of_item': 'total_item',
                                        'order_id': 'total_order',
                                        'session_id': 'total_session'})

df_grouped = df_grouped[df_grouped['recency'] < 180]
print(df_grouped.info())
df_grouped.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8863 entries, 1 to 17800
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   user_id                    8863 non-null   object
#  1   country                    8863 non-null   object
#  2   gender                     8863 non-null   object
#  3   traffic_source             8863 non-null   object
#  4   age                        8863 non-null   Int64
#  5   total_order                8863 non-null   int64
#  6   total_item                 8863 non-null   Int64
#  7   revenue                    8863 non-null   float64
#  8   total_session              8863 non-null   int64
#  9   recency                    8863 non-null   float64
#  10  age_account                8863 non-null   float64
#  11  diff_last_order_to_create  8863 non-null   float64
# dtypes: Int64(2), float64(4), int64(2), object(4)
# memory usage: 917.5+ KB
# None
#    user_id        country gender traffic_source  age  total_order  total_item  \
# 1    10013  United States      M         Search   43            1           1
# 3    10022  United States      F        Display   57            1           1
# 5    10030         Brasil      M         Search   52            1           1
# 7    10042  United States      M         Search   19            1           4
# 10   10065         Brasil      F        Organic   60            1           1
#
#        revenue  total_session  recency  age_account  diff_last_order_to_create
# 1   100.800003              1     92.0        213.0                      121.0
# 3     6.990000              1     61.0         92.0                       31.0
# 5   293.329987              1    121.0       1766.0                     1645.0
# 7   557.500000              2    152.0        486.0                      334.0
# 10   19.520000              1    152.0        397.0                      245.0

# %%
df_grouped.describe()
# Out:
#              age  total_order  total_item      revenue  total_session  \
# count     8863.0  8863.000000      8863.0  8863.000000    8863.000000
# mean    41.32111     1.146226    3.129414   189.241095       1.659935
# std    16.916552     0.394399       3.978   306.828329       1.028868
# min         12.0     1.000000         1.0     1.750000       1.000000
# 25%         27.0     1.000000         1.0    33.750000       1.000000
# 50%         41.0     1.000000         1.0    75.000000       1.000000
# 75%         56.0     1.000000         4.0   198.430000       2.000000
# max         70.0     4.000000        36.0  4491.800003      10.000000
#
#            recency  age_account  diff_last_order_to_create
# count  8863.000000  8863.000000                8863.000000
# mean     68.450073   525.710482                 457.260408
# std      49.666595   524.148801                 510.475608
# min       0.000000     0.000000                   0.000000
# 25%      31.000000   121.000000                  60.000000
# 50%      61.000000   336.000000                 244.000000
# 75%     121.000000   792.000000                 730.000000
# max     152.000000  1978.000000                1978.000000

# %%
map_rename = {
    'F': 'Female',
    'M': 'Male',
    'United States': 'United_States'
}

# low_variance = ['total_item', 'total_order']

# Copy dataframe
df_enc_scaled = df_grouped.copy()

# Bin age
df_enc_scaled['age'] = pd.qcut(df_grouped['age'], q=3, labels=['Teen', 'Adult', 'Old'])

# Encoding
encoded_columns = ['country', 'gender', 'traffic_source', 'age']
for c in encoded_columns:
    temp = pd.get_dummies(df_enc_scaled[c]).astype(int)
    df_enc_scaled = pd.concat([df_enc_scaled, temp], axis=1)

# df_enc_scaled = df_enc_scaled.drop(encoded_columns + low_variance, axis=1).rename(columns=map_rename)
df_enc_scaled = df_enc_scaled.drop(encoded_columns, axis=1).rename(columns=map_rename)

# StandardScaler numeric data
sc = StandardScaler()
sc_columns = ['revenue', 'recency', 'age_account', 'diff_last_order_to_create']

df_enc_scaled[sc_columns] = sc.fit_transform(df_enc_scaled[sc_columns])

print(df_enc_scaled.info())
df_enc_scaled.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8863 entries, 1 to 17800
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   user_id                    8863 non-null   object
#  1   total_order                8863 non-null   int64
#  2   total_item                 8863 non-null   Int64
#  3   revenue                    8863 non-null   float64
#  4   total_session              8863 non-null   int64
#  5   recency                    8863 non-null   float64
#  6   age_account                8863 non-null   float64
#  7   diff_last_order_to_create  8863 non-null   float64
#  8   Brasil                     8863 non-null   int32
#  9   China                      8863 non-null   int32
#  10  Others                     8863 non-null   int32
#  11  United_States              8863 non-null   int32
#  12  Female                     8863 non-null   int32
#  13  Male                       8863 non-null   int32
#  14  Display                    8863 non-null   int32
#  15  Email                      8863 non-null   int32
#  16  Facebook                   8863 non-null   int32
#  17  Organic                    8863 non-null   int32
#  18  Search                     8863 non-null   int32
#  19  Teen                       8863 non-null   int32
#  20  Adult                      8863 non-null   int32
#  21  Old                        8863 non-null   int32
# dtypes: Int64(1), float64(4), int32(14), int64(2), object(1)
# memory usage: 1.1+ MB
# None
#    user_id  total_order  total_item   revenue  total_session   recency  \
# 1    10013            1           1 -0.288259              1  0.474187
# 3    10022            1           1 -0.594017              1 -0.150010
# 5    10030            1           1  0.339261              1  1.058113
# 7    10042            1           4  1.200279              2  1.682311
# 10   10065            1           1 -0.553178              1  1.682311
#
#     age_account  diff_last_order_to_create  Brasil  China  ...  Female  Male  \
# 1     -0.596640                  -0.658757       0      0  ...       0     1
# 3     -0.827503                  -0.835073       0      0  ...       1     0
# 5      2.366426                   2.326863       1      0  ...       0     1
# 7     -0.075766                  -0.241476       0      0  ...       0     1
# 10    -0.245575                  -0.415833       1      0  ...       1     0
#
#     Display  Email  Facebook  Organic  Search  Teen  Adult  Old
# 1         0      0         0        0       1     0      1    0
# 3         1      0         0        0       0     0      0    1
# 5         0      0         0        0       1     0      0    1
# 7         0      0         0        0       1     1      0    0
# 10        0      0         0        1       0     0      0    1
#
# [5 rows x 22 columns]

# %% [markdown]
# **KMeans**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

X = df_enc_scaled.drop('user_id', axis=1)
distortions = []
for i in range(1, 11):
    km = KMeans(n_clusters=i,
                init='k-means++',
                n_init=10,
                max_iter=300,
                random_state=0)
    
    km.fit(X)
    distortions.append(km.inertia_)
    
plt.plot(range(1, 11), distortions, marker='o')
plt.xlabel("Number of clusters")
plt.ylabel("Distortions")
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import silhouette_samples
from matplotlib import cm

km = KMeans(n_clusters=3,
            init='k-means++',
            n_init=10,
            max_iter=300,
            tol=1e-04,
            random_state=0)

y_km = km.fit_predict(X)

cluster_labels = np.unique(y_km)
n_clusters = cluster_labels.shape[0]
silhouette_vals = silhouette_samples(X, y_km, metric='euclidean')
y_ax_lower, y_ax_upper = 0, 0
yticks = []
for i, c in enumerate(cluster_labels):
    c_silhouette_vals = silhouette_vals[y_km == c]
    c_silhouette_vals.sort()
    y_ax_upper += len(c_silhouette_vals)
    color = cm.jet(float(i) / n_clusters)
    plt.barh(range(y_ax_lower, y_ax_upper),
             c_silhouette_vals,
             height=1.0,
             edgecolor='none',
             color=color)
    yticks.append((y_ax_lower + y_ax_upper) / 2.)
    y_ax_lower += len(c_silhouette_vals)

silhouette_avg = np.mean(silhouette_vals)
print(silhouette_avg)
plt.axvline(silhouette_avg,
            color='red',
            linestyle='--')
plt.yticks(yticks, cluster_labels + 1)
plt.ylabel("Cluster")
plt.xlabel("Silhouette coefficient")
plt.tight_layout()
plt.show()
# Out:
# 0.37008124749938365

# %%
import seaborn as sns
from sklearn.decomposition import PCA

km = KMeans(n_clusters=3,
            init='k-means++',
            n_init=10,
            max_iter=300,
            random_state=0).fit(X)


labels = list(km.labels_)

result = df_grouped.copy()

result['cluster'] = labels

print(df_grouped.info())

# Decompose fields
pca = PCA(n_components=2)

transform = pca.fit_transform(df_enc_scaled.drop('user_id', axis=1).values)

result[['PCA1', 'PCA2']] = transform

sns.scatterplot(data=result, y= 'PCA1', x='revenue', hue='cluster',)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8863 entries, 1 to 17800
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   user_id                    8863 non-null   object
#  1   country                    8863 non-null   object
#  2   gender                     8863 non-null   object
#  3   traffic_source             8863 non-null   object
#  4   age                        8863 non-null   Int64
#  5   total_order                8863 non-null   int64
#  6   total_item                 8863 non-null   Int64
#  7   revenue                    8863 non-null   float64
#  8   total_session              8863 non-null   int64
#  9   recency                    8863 non-null   float64
#  10  age_account                8863 non-null   float64
#  11  diff_last_order_to_create  8863 non-null   float64
# dtypes: Int64(2), float64(4), int64(2), object(4)
# memory usage: 917.5+ KB
# None

# %%
pivot_table = result.pivot_table(
    values=['recency', 'revenue', 'age', 'age_account', 'diff_last_order_to_create', 'total_order', 'total_item', 'total_session'],
    index='cluster',
    aggfunc=['mean', 'max', 'min', 'median']
)

pivot_table
# Out:
#               mean                                                   \
#                age age_account diff_last_order_to_create    recency
# cluster
# 0         41.17292  515.496330                446.676591  68.819739
# 1        42.067416  467.082397                402.140449  64.941948
# 2        41.315127  535.299132                466.684533  68.614599
#
#                                                          max              ...  \
#             revenue total_item total_order total_session age age_account  ...
# cluster                                                                   ...
# 0        310.958871   5.165171    1.246330      2.433524  70      1978.0  ...
# 1        999.083689  16.297753    1.376404      4.451311  70      1947.0  ...
# 2         64.873572   1.083546    1.083546      1.083546  70      1978.0  ...
#
#                 min               median              \
#         total_order total_session    age age_account
# cluster
# 0                 1             2   41.0       336.0
# 1                 1             3   42.5       274.0
# 2                 1             1   41.0       336.0
#
#                                                                               \
#         diff_last_order_to_create recency     revenue total_item total_order
# cluster
# 0                           244.0    61.0  229.970001        4.0         1.0
# 1                           213.0    61.0  876.639996       16.0         1.0
# 2                           245.0    61.0   43.990002        1.0         1.0
#
#
#         total_session
# cluster
# 0                 2.0
# 1                 4.0
# 2                 1.0
#
# [3 rows x 32 columns]

# %% [markdown]
# **Hierarchical**

# %%
km = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage='ward')

y_km = km.fit_predict(X)

cluster_labels = np.unique(y_km)
n_clusters = cluster_labels.shape[0]
silhouette_vals = silhouette_samples(X, y_km, metric='euclidean')
y_ax_lower, y_ax_upper = 0, 0
yticks = []
for i, c in enumerate(cluster_labels):
    c_silhouette_vals = silhouette_vals[y_km == c]
    c_silhouette_vals.sort()
    y_ax_upper += len(c_silhouette_vals)
    color = cm.jet(float(i) / n_clusters)
    plt.barh(range(y_ax_lower, y_ax_upper),
             c_silhouette_vals,
             height=1.0,
             edgecolor='none',
             color=color)
    yticks.append((y_ax_lower + y_ax_upper) / 2.)
    y_ax_lower += len(c_silhouette_vals)

silhouette_avg = np.mean(silhouette_vals)
print(silhouette_avg)
plt.axvline(silhouette_avg,
            color='red',
            linestyle='--')
plt.yticks(yticks, cluster_labels + 1)
plt.ylabel("Cluster")
plt.xlabel("Silhouette coefficient")
plt.tight_layout()
plt.show()
# Out:
# 0.37143176402957684

# %%
import seaborn as sns
from sklearn.decomposition import PCA

labels = list(y_km)

result = df_grouped.copy()

result['cluster'] = labels

print(df_grouped.info())

# Decompose fields
pca = PCA(n_components=2)

transform = pca.fit_transform(df_enc_scaled.drop('user_id', axis=1).values)

result[['PCA1', 'PCA2']] = transform

sns.scatterplot(data=result, y= 'PCA1', x='revenue', hue='cluster',)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8863 entries, 1 to 17800
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   user_id                    8863 non-null   object
#  1   country                    8863 non-null   object
#  2   gender                     8863 non-null   object
#  3   traffic_source             8863 non-null   object
#  4   age                        8863 non-null   Int64
#  5   total_order                8863 non-null   int64
#  6   total_item                 8863 non-null   Int64
#  7   revenue                    8863 non-null   float64
#  8   total_session              8863 non-null   int64
#  9   recency                    8863 non-null   float64
#  10  age_account                8863 non-null   float64
#  11  diff_last_order_to_create  8863 non-null   float64
# dtypes: Int64(2), float64(4), int64(2), object(4)
# memory usage: 917.5+ KB
# None

# %%
pivot_table = result.pivot_table(
    values=['recency', 'revenue', 'age', 'age_account', 'diff_last_order_to_create', 'total_order', 'total_item', 'total_session'],
    index='cluster',
    aggfunc=['mean', 'max', 'min', 'median']
)

pivot_table
# Out:
#               mean                                                   \
#                age age_account diff_last_order_to_create    recency
# cluster
# 0        41.164953  517.378034                448.379268  68.998766
# 1        41.990385  465.546154                400.378846  65.167308
# 2        41.326455  534.428620                465.915426  68.513194
#
#                                                           max              \
#              revenue total_item total_order total_session age age_account
# cluster
# 0         316.062913   5.229124    1.228712      2.438503  70      1978.0
# 1        1000.856000  16.440385    1.340385      4.440385  70      1947.0
# 2          65.705305    1.09523    1.095230      1.095230  70      1978.0
#
#                                                                                \
#         diff_last_order_to_create recency      revenue total_item total_order
# cluster
# 0                          1947.0   152.0  3777.000000         13           4
# 1                          1919.0   152.0  4491.800003         36           4
# 2                          1978.0   152.0   999.000000          4           4
#
#                       min                                                \
#         total_session age age_account diff_last_order_to_create recency
# cluster
# 0                   6  12         0.0                       0.0     0.0
# 1                  10  12         0.0                       0.0     0.0
# 2                   4  12         0.0                       0.0     0.0
#
#                                                          median              \
#             revenue total_item total_order total_session    age age_account
# cluster
# 0         27.120000          4           1             2   41.0       336.0
# 1        218.320004         13           1             4   42.0       274.0
# 2          1.750000          1           1             1   41.0       336.0
#
#                                                                               \
#         diff_last_order_to_create recency     revenue total_item total_order
# cluster
# 0                           244.0    61.0  231.360001        4.0         1.0
# 1                           198.5    61.0  878.699999       16.0         1.0
# 2                           245.0    61.0   44.000000        1.0         1.0
#
#
#         total_session
# cluster
# 0                 2.0
# 1                 4.0
# 2                 1.0

# %% [markdown]
# **Kernel Kmeans**

# %%
from sklearn.decomposition import KernelPCA

# Kernel K-Means

# Apply Kernel PCA with RBF kernel
kpca = KernelPCA(n_components=2, kernel='rbf', gamma=1.0)
X_kpca = kpca.fit_transform(X)

distortions = []
for i in range(1, 11):
    km = KMeans(n_clusters=i,
                init='k-means++',
                n_init=10,
                max_iter=300,
                random_state=0)
    
    km.fit(X_kpca)
    distortions.append(km.inertia_)
    
plt.plot(range(1, 11), distortions, marker='o')
plt.xlabel("Number of clusters")
plt.ylabel("Distortions")
plt.tight_layout()
plt.show()

# %%
km = KMeans(n_clusters=3,
            init='k-means++',
            n_init=10,
            max_iter=300,
            tol=1e-04,
            random_state=0)

y_km = km.fit_predict(X_kpca)

cluster_labels = np.unique(y_km)
n_clusters = cluster_labels.shape[0]
silhouette_vals = silhouette_samples(X_kpca, y_km, metric='euclidean')
y_ax_lower, y_ax_upper = 0, 0
yticks = []
for i, c in enumerate(cluster_labels):
    c_silhouette_vals = silhouette_vals[y_km == c]
    c_silhouette_vals.sort()
    y_ax_upper += len(c_silhouette_vals)
    color = cm.jet(float(i) / n_clusters)
    plt.barh(range(y_ax_lower, y_ax_upper),
             c_silhouette_vals,
             height=1.0,
             edgecolor='none',
             color=color)
    yticks.append((y_ax_lower + y_ax_upper) / 2.)
    y_ax_lower += len(c_silhouette_vals)

silhouette_avg = np.mean(silhouette_vals)
print(silhouette_avg)
plt.axvline(silhouette_avg,
            color='red',
            linestyle='--')
plt.yticks(yticks, cluster_labels + 1)
plt.ylabel("Cluster")
plt.xlabel("Silhouette coefficient")
plt.tight_layout()
plt.show()
# Out:
# 0.803635587341222

# %%
df_grouped['cluster'] = y_km

df_grouped[['PCA1', 'PCA2']] = X_kpca
# df_grouped[['PCA1', 'PCA2', 'PCA3']] = X_kpca
# df_grouped[['PCA1', 'PCA2', 'PCA3', 'PCA4']] = X_kpca

sns.scatterplot(data=df_grouped, y= 'PCA2', x='PCA1', hue='cluster',)
plt.show()


print(df_grouped.info())
df_grouped.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8863 entries, 1 to 17800
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   user_id                    8863 non-null   object
#  1   country                    8863 non-null   object
#  2   gender                     8863 non-null   object
#  3   traffic_source             8863 non-null   object
#  4   age                        8863 non-null   Int64
#  5   total_order                8863 non-null   int64
#  6   total_item                 8863 non-null   Int64
#  7   revenue                    8863 non-null   float64
#  8   total_session              8863 non-null   int64
#  9   recency                    8863 non-null   float64
#  10  age_account                8863 non-null   float64
#  11  diff_last_order_to_create  8863 non-null   float64
#  12  cluster                    8863 non-null   int32
#  13  PCA1                       8863 non-null   float64
#  14  PCA2                       8863 non-null   float64
#  15  PCA3                       8863 non-null   float64
#  16  PCA4                       8863 non-null   float64
# dtypes: Int64(2), float64(8), int32(1), int64(2), object(4)
# memory usage: 1.2+ MB
# None
#    user_id        country gender traffic_source  age  total_order  total_item  \
# 1    10013  United States      M         Search   43            1           1
# 3    10022  United States      F        Display   57            1           1
# 5    10030         Brasil      M         Search   52            1           1
# 7    10042  United States      M         Search   19            1           4
# 10   10065         Brasil      F        Organic   60            1           1
#
#        revenue  total_session  recency  age_account  \
# 1   100.800003              1     92.0        213.0
# 3     6.990000              1     61.0         92.0
# 5   293.329987              1    121.0       1766.0
# 7   557.500000              2    152.0        486.0
# 10   19.520000              1    152.0        397.0
#
#     diff_last_order_to_create  cluster      PCA1      PCA2      PCA3      PCA4
# 1                       121.0        0 -0.032699  0.095110 -0.068751  0.060587
# 3                        31.0        0 -0.020149 -0.020304  0.020704  0.005092
# 5                      1645.0        0 -0.033612 -0.017788  0.002490  0.004564
# 7                       334.0        0 -0.032094 -0.016946  0.002401  0.004323
# 10                      245.0        0 -0.036158 -0.022211  0.003084  0.005261

# %%
pivot_table = df_grouped.pivot_table(
    values=['recency', 'revenue', 'age', 'age_account', 'diff_last_order_to_create'],
    index='cluster',
    aggfunc=['mean', 'max', 'min', 'median']
)

pivot_table
# Out:
#               mean                                                   \
#                age age_account diff_last_order_to_create    recency
# cluster
# 0        41.733282  578.247484                504.831741  73.415743
# 1        41.543947  113.001658                 88.250415  24.751244
# 2        33.080685  125.699267                 88.141809  37.557457
#
#                     max                                                \
#             revenue age age_account diff_last_order_to_create recency
# cluster
# 0        206.814766  70      1978.0                    1978.0   152.0
# 1         56.327877  70       548.0                     517.0    92.0
# 2         47.861565  70       578.0                     517.0   121.0
#
#                      min                                                \
#              revenue age age_account diff_last_order_to_create recency
# cluster
# 0        4491.800003  12         0.0                       0.0     0.0
# 1         299.000000  12         0.0                       0.0     0.0
# 2         295.929993  12         0.0                       0.0     0.0
#
#                 median                                                \
#         revenue    age age_account diff_last_order_to_create recency
# cluster
# 0          1.75   42.0       397.0                     305.0    61.0
# 1          3.88   41.0        61.0                      31.0    31.0
# 2          3.50   28.0        92.0                      31.0    31.0
#
#
#            revenue
# cluster
# 0        87.970001
# 1        42.000000
# 2        36.000000

# %% [markdown]
# **Hierarcichal**

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import AgglomerativeClustering

# Perform clustering
cluster = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage='ward')
labels = cluster.fit_predict(X_kpca)

# Evaluate with silhouette score
silhouette_avg = silhouette_score(X_kpca, labels)
print(f'Silhouette Score: {silhouette_avg}')
# Out:
# Silhouette Score: 0.6823546301989765

# %%
pivot_table = df_grouped.pivot_table(
    values=['recency', 'revenue', 'age', 'age_account', 'diff_last_order_to_create'],
    index='cluster',
    aggfunc=['mean', 'max', 'min', 'median']
)

pivot_table
# Out:
#               mean                                                   \
#                age age_account diff_last_order_to_create    recency
# cluster
# 0        38.950254  158.807107                114.578680  44.228426
# 1        40.493756  184.108549                138.970221  45.138329
# 2         41.78865  630.582127                555.093023  75.489103
#
#                     max                                                \
#             revenue age age_account diff_last_order_to_create recency
# cluster
# 0         54.116376  70       792.0                     700.0   152.0
# 1         58.699731  70       762.0                     670.0   152.0
# 2        228.584580  70      1978.0                    1978.0   152.0
#
#                      min                                                \
#              revenue age age_account diff_last_order_to_create recency
# cluster
# 0         378.000000  12         0.0                       0.0     0.0
# 1         399.000000  12         0.0                       0.0     0.0
# 2        4491.800003  12         0.0                       0.0     0.0
#
#                 median                                                \
#         revenue    age age_account diff_last_order_to_create recency
# cluster
# 0          2.99   38.0       121.0                      61.0    31.0
# 1          4.38   41.0       121.0                      62.0    31.0
# 2          1.75   42.0       458.0                     394.0    61.0
#
#
#             revenue
# cluster
# 0         38.000000
# 1         39.990002
# 2        102.000000
