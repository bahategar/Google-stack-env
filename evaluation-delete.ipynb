# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_cat = pd.read_csv('./result/data_modeling.csv')
print(df_cat.info())
df_cat.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2170 entries, 0 to 2169
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   category                               2170 non-null   object
#  1   date                                   2170 non-null   object
#  2   total_hits                             2170 non-null   float64
#  3   total_visits                           2170 non-null   float64
#  4   total_page_views                       2170 non-null   float64
#  5   total_first_visits                     2170 non-null   float64
#  6   total_time_on_site                     2170 non-null   float64
#  7   avg_time_on_site                       2170 non-null   float64
#  8   total_transactions                     2170 non-null   float64
#  9   total_revenue                          2170 non-null   float64
# ...

# %%
df_cat['date'] = pd.to_datetime(df_cat['date'])

# %%
print(df_cat.info())
df_cat.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2170 entries, 0 to 2169
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   category                               2170 non-null   object
#  1   date                                   2170 non-null   datetime64[ns]
#  2   total_hits                             2170 non-null   float64
#  3   total_visits                           2170 non-null   float64
#  4   total_page_views                       2170 non-null   float64
#  5   total_first_visits                     2170 non-null   float64
#  6   total_time_on_site                     2170 non-null   float64
#  7   avg_time_on_site                       2170 non-null   float64
#  8   total_transactions                     2170 non-null   float64
#  9   total_revenue                          2170 non-null   float64
# ...

# %%
df

# %%
df_cat[df_cat['category'] == 'Accessories'][['total_visits', 'total_first_visits', 'total_transactions', 'total_revenue']].sum()
# Out:
# total_visits          9.742214e+03
# total_first_visits    5.352467e+03
# total_transactions    2.023681e+03
# total_revenue         3.423348e+11
# dtype: float64
